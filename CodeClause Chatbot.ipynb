# %%
import nltk
from nltk.chat.util import Chat, reflections

# %%
reflections = {
  "i am"       : "you are",
  "i was"      : "you were",
  "i"          : "you",
  "i'm"        : "you are",
  "i'd"        : "you would",
  "i've"       : "you have",
  "i'll"       : "you will",
  "my"         : "your",
  "you are"    : "I am",
  "you were"   : "I was",
  "you've"     : "I have",
  "you'll"     : "I will",
  "your"       : "my",
  "yours"      : "mine",
  "you"        : "me",
  "me"         : "you"
}

# %%
pairs = [
    [
        r"yes",
        ["which type of internship you want?\n1. Data Science\n2. Artificial Intelligence\n3. Python Development\n4. Web Development\n5. Android Development\n6. Java Developer\n7. Graphic Designer\n8. Content Writer",]
    ],
        [
        r"repeat",
        ["We offer a wide variety of internships. Which type of internship you want?\n1.Data Science\n2.Artificial Intelligence\n3.Python Development\n4.Web Development\n5.Android Development\n6.Java Developer\n7.Graphic Designer\n8.Content Writer",]
    ],
    [
        r"1",
        ["Data Science Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/Apply?jobid=12143",]
    ], 
    [
        r"2",
        ["Artificial Intelligence Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/apply?jobid=12244",]
    ],
    [
        r"3",
        ["Python Development Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/apply?jobid=9876",]
    ],
    [
        r"4",
        ["Web Development Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/apply?jobid=12345",]
    ],
    [
        r"5",
        ["Android Development Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/apply?jobid=12446",]
    ],
    [
        r"6",
        ["Java Developer Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/apply?jobid=12547",]
    ],
       [
        r"7",
        ["Graphic Designer Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/apply?jobid=12648",]
    ],

    [
        r"8",
        ["Content Writer Internship Details\nJob Type- Intern \nLocation- Remote Work \nDuration- 4 Weeks\nFill form from given link : https://internship.codeclause.com/apply?jobid=12649",]
    ],

    [
        r"quit",
        ["Bye take care. See you soon. To know more about us, go to https://codeclause.com/ \nOr contact on : info@codeclause.com Or official@codeclause.com",]
    ],
    [
        r"thanks",
        ["Your Welcome! To know more about us, go to https://codeclause.com/ \nOr contact on : info@codeclause.com Or official@codeclause.com",]
    ]
]

# %%
#Start the chat
def chat():
    print("CodeClause is a Pune-based IT Company that provides IT solutions as well as internships in various computer science domains. We also develop software tailored to our customers' requirements.")
    print("You can find more information about the company on our official portal: https://codeclause.com/\n")
    print("If you're interested in our internships, feel free to ask!\n")
    chatbot = Chat(pairs, reflections)
    chatbot.converse()

if __name__ == "__main__":
    chat()
# Out:
# CodeClause is a Pune-based IT Company that provides IT solutions as well as internships in various computer science domains. We also develop software tailored to our customers' requirements.
# You can find more information about the company on our official portal: https://codeclause.com/
#
# If you're interested in our internships, feel free to ask!
#
# >yes
# which type of internship you want?
# 1. Data Science
# 2. Artificial Intelligence
# 3. Python Development
# 4. Web Development
# 5. Android Development
# 6. Java Developer
# 7. Graphic Designer
# 8. Content Writer
# >1
# Data Science Internship Details
# Job Type- Intern
# Location- Remote Work
# Duration- 4 Weeks
# Fill form from given link : https://internship.codeclause.com/Apply?jobid=12143
# >repeat
# We offer a wide variety of internships. Which type of internship you want?
# 1.Data Science
# 2.Artificial Intelligence
# 3.Python Development
# 4.Web Development
# 5.Android Development
# 6.Java Developer
# 7.Graphic Designer
# 8.Content Writer
# >2
# Artificial Intelligence Internship Details
# Job Type- Intern
# Location- Remote Work
# Duration- 4 Weeks
# Fill form from given link : https://internship.codeclause.com/apply?jobid=12244
# >thanks
# Your Welcome! To know more about us, go to https://codeclause.com/
# Or contact on : info@codeclause.com Or official@codeclause.com
# >quit
# Bye take care. See you soon. To know more about us, go to https://codeclause.com/
# Or contact on : info@codeclause.com Or official@codeclause.com
